# %% [markdown]
# <a href="https://colab.research.google.com/github/moonsy0311/-/blob/main/%5B%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D%EC%9D%84_%EC%9C%84%ED%95%9C_Numpy_%26_Pandas%5D_6%ED%9A%8C%EC%B0%A8_Pandas_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%8B%9C%EA%B0%81%ED%99%94_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![KakaoTalk_20230803_163633393.png](data:image/png;base64,...)

# %% [markdown]
# <img src="https://pandas.pydata.org/static/img/pandas.svg" height="100">

# %%
# Pandas 패키지 불러오기
import pandas as pd

# %% [markdown]
# ---

# %% [markdown]
# # 1.Data Science Salaries

# %% [markdown]
# https://www.kaggle.com/datasets/arnabchaki/data-science-salaries-2023

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
data = pd.read_excel("/content/Data Science Salaries 2023.xlsx")

# %% [markdown]
# ### 1.1. 데이터 살펴보기

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 322.8+ KB

# %% [markdown]
# > Column 정보
# * work_year: 근무 연도
# * experience_level: 경험 수준 (예: SE - Senior, MI - Mid-level)
# * employment_type: 고용 형태 (예: FT - Full-time, CT - Contract)
# * job_title: 직책 (예: Principal Data Scientist, ML Engineer)
# * salary: 해당 salary_currency로 표시된 급여
# * salary_currency: 급여의 통화 단위
# * salary_in_usd: USD로 환산된 급여
# * employee_residence: 직원의 거주 국가
# * remote_ratio: 원격 근무 비율 (백분율)
# * company_location: 회사 위치
# * company_size: 회사 규모 (예: S - Small, M - Medium, L - Large)

# %%
data.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# 1               US            S
# 2               US            S
# 3               CA            M
# 4               CA            M

# %%
data.tail()
# Out:
#       work_year experience_level employment_type                 job_title  \
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
#      company_location company_size
# 3750               US            L
# 3751               US            L
# 3752               US            S
# 3753               US            L
# 3754               IN            L

# %% [markdown]
# ## 1.2. 한글 컬럼명으로 바꾸기

# %%
data.columns
# Out:
# Index(['근무연도', '경험수준', '고용형태', '직책', '급여', '급여통화', 'USD환산급여', '거주국가', '원격근무비율',
#        '회사위치', '회사규모', 'KRW환산급여', '경험수준_한글'],
#       dtype='object')

# %%
data.columns = [
    '근무연도',
    '경험수준',
    '고용형태',
    '직책',
    '급여',
    '급여통화',
    'USD환산급여',
    '거주국가',
    '원격근무비율',
    '회사위치',
    '회사규모'
]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-d9c7322755e9> in <cell line: 1>()
# ----> 1 data.columns = [
#       2     '근무연도',
#       3     '경험수준',
#       4     '고용형태',
#       5     '직책',
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    6000         try:
#    6001             object.__getattribute__(self, name)
# -> 6002             return object.__setattr__(self, name, value)
#    6003         except AttributeError:
#    6004             pass
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     728         """
#     729         labels = ensure_index(labels)
# --> 730         self._mgr.set_axis(axis, labels)
#     731         self._clear_item_cache()
#     732
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     223     def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     224         # Caller is responsible for ensuring we have an Index object.
# --> 225         self._validate_set_axis(axis, new_labels)
#     226         self.axes[axis] = new_labels
#     227
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
#      68
#      69         elif new_len != old_len:
# ---> 70             raise ValueError(
#      71                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      72                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 13 elements, new values have 11 elements

# %%
data
# Out:
#       근무연도 경험수준 고용형태                        직책       급여 급여통화  USD환산급여 거주국가  \
# 0     2023   SE   FT  Principal Data Scientist    80000  EUR    85847   ES
# 1     2023   MI   CT               ML Engineer    30000  USD    30000   US
# 2     2023   MI   CT               ML Engineer    25500  USD    25500   US
# 3     2023   SE   FT            Data Scientist   175000  USD   175000   CA
# 4     2023   SE   FT            Data Scientist   120000  USD   120000   CA
# ...    ...  ...  ...                       ...      ...  ...      ...  ...
# 3750  2020   SE   FT            Data Scientist   412000  USD   412000   US
# 3751  2021   MI   FT  Principal Data Scientist   151000  USD   151000   US
# 3752  2020   EN   FT            Data Scientist   105000  USD   105000   US
# 3753  2020   EN   CT     Business Data Analyst   100000  USD   100000   US
# 3754  2021   SE   FT      Data Science Manager  7000000  INR    94665   IN
#
#       원격근무비율 회사위치 회사규모       KRW환산급여 경험수준_한글
# 0        100   ES    L  1.187341e+08      고위
# 1        100   US    S  4.149270e+07      중간
# 2        100   US    S  3.526880e+07      중간
# 3        100   CA    M  2.420408e+08      고위
# 4        100   CA    M  1.659708e+08      고위
# ...      ...  ...  ...           ...     ...
# 3750     100   US    L  5.698331e+08      고위
# 3751     100   US    L  2.088466e+08      중간
# 3752     100   US    S  1.452244e+08      신입
# 3753     100   US    L  1.383090e+08      신입
# 3754      50   IN    L  1.309302e+08      고위
#
# [3755 rows x 13 columns]

# %% [markdown]
# # 2.한글 폰트 설치하기

# %%
# 한글 폰트 설치
! rm -rf NanumFont*
! wget http://cdn.naver.com/naver/NanumFont/fontfiles/NanumFont_TTF_ALL.zip
! unzip NanumFont_TTF_ALL.zip -d NanumFont
! rm -rf NanumFont_TTF_ALL.zip
# Out:
# --2024-06-28 02:35:53--  http://cdn.naver.com/naver/NanumFont/fontfiles/NanumFont_TTF_ALL.zip
# Resolving cdn.naver.com (cdn.naver.com)... 183.111.124.155, 211.47.29.199, 183.111.124.156
# Connecting to cdn.naver.com (cdn.naver.com)|183.111.124.155|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14946146 (14M) [application/zip]
# Saving to: ‘NanumFont_TTF_ALL.zip’
#
# NanumFont_TTF_ALL.z 100%[===================>]  14.25M  5.82MB/s    in 2.4s
#
# 2024-06-28 02:35:57 (5.82 MB/s) - ‘NanumFont_TTF_ALL.zip’ saved [14946146/14946146]
#
# Archive:  NanumFont_TTF_ALL.zip
#   inflating: NanumFont/NanumBrush.ttf
#   inflating: NanumFont/NanumGothic.ttf
#   inflating: NanumFont/NanumGothicBold.ttf
#   inflating: NanumFont/NanumGothicExtraBold.ttf
#   inflating: NanumFont/NanumMyeongjo.ttf
#   inflating: NanumFont/NanumMyeongjoBold.ttf
#   inflating: NanumFont/NanumMyeongjoExtraBold.ttf
#   inflating: NanumFont/NanumPen.ttf

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager

font_path = '/content/NanumFont/NanumGothic.ttf'
font_manager.fontManager.addfont(font_path)
prop = font_manager.FontProperties(fname=font_path)
plt.rcParams['font.family'] = prop.get_name()
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 3.scatter plot

# %%
# 환율 정보를 가져와서 USD를 KRW로 변환
usd_to_krw_rate = 1383.09
data['KRW환산급여'] = data['USD환산급여'] * usd_to_krw_rate

# 경험수준 컬럼을 한글로 변환한 새로운 컬럼 생성
data['경험수준_한글'] = data['경험수준'].map({
    'EX': '임원',
    'SE': '고위',
    'MI': '중간',
    'EN': '신입'
})

# %%
data.head(1)
# Out:
#    근무연도 경험수준 고용형태                        직책     급여 급여통화  USD환산급여 거주국가  원격근무비율  \
# 0  2023   SE   FT  Principal Data Scientist  80000  EUR    85847   ES     100
#
#   회사위치 회사규모       KRW환산급여 경험수준_한글
# 0   ES    L  1.187341e+08      고위

# %%
data.plot.scatter(x="경험수준_한글", y="KRW환산급여")
# Out:
# <Axes: xlabel='경험수준_한글', ylabel='KRW환산급여'>

# %%
import seaborn as sns

# Create a scatter plot with regression line for '경험수준_한글' vs 'KRW환산급여'
plt.figure(figsize=(10, 6))
sns.regplot(
    x=data['경험수준_한글'].map({'신입': 1, '중간': 2, '고위': 3, '임원': 4}),
    y=data['KRW환산급여'],
    scatter_kws={'s': 50},
    line_kws={'color': 'red'}
)
plt.title('경험수준별 KRW 환산급여 (회귀선 포함)')
plt.xlabel('경험수준')
plt.ylabel('KRW 환산급여')
plt.xticks(ticks=[1, 2, 3, 4], labels=['신입', '중간', '고위', '임원'])
plt.grid(True)
plt.show()

# %% [markdown]
# # 4.box plot

# %%
data.plot.box(by="경험수준_한글", column="KRW환산급여")
# Out:
# KRW환산급여    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
data['경험수준_한글'] = pd.Categorical(data['경험수준_한글'], categories=['신입', '중간', '고위', '임원'], ordered=True)

# 박스의 속성을 정의합니다. 실선 스타일, 선 너비 3, 색상은 어두운 황금색입니다.
boxprops = dict(linestyle='-', linewidth=3, color='darkgoldenrod')
# 이상치(flier)의 속성을 정의합니다. 마커는 'o', 색상은 빨간색, 투명도는 0.5입니다.
flierprops = dict(marker='o', color='red', alpha=0.5)
# 중앙값(median)의 속성을 정의합니다. 실선 스타일, 선 너비 2.5, 색상은 파이어브릭(짙은 붉은색)입니다.
medianprops = dict(linestyle='-', linewidth=2.5, color='firebrick')
# 평균(mean) 포인트의 속성을 정의합니다. 마커는 'D', 마커 테두리 색상은 검정색, 마커 내부 색상은 파이어브릭입니다.
meanpointprops = dict(marker='D', markeredgecolor='black', markerfacecolor='firebrick')

data.boxplot(
    column='KRW환산급여',
    by='경험수준_한글',
    boxprops=boxprops,
    flierprops=flierprops,
    medianprops=medianprops,
    meanprops=meanpointprops,
    showmeans=True,
    patch_artist=True,
    figsize=(12, 8)
)

plt.title('경험수준별 KRW 환산급여 분포', fontsize=16)
plt.suptitle('')  # Suppress the default title
plt.xlabel('경험수준', fontsize=14)
plt.ylabel('KRW 환산급여', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# # 5.histogram plot

# %%
data.KRW환산급여.hist()
# Out:
# <Axes: >

# %%
data['KRW환산급여'].plot.hist(
    figsize=(12, 8),  # 그래프 크기 설정 (가로 12인치, 세로 8인치)
    bins=30,  # 30개의 구간 적용
    color='#66B2FF',  # 막대 색상 설정
    edgecolor='black',  # 막대 테두리 색상 설정
    alpha=0.7,  # 막대 투명도 설정
    title='KRW 환산급여 분포'  # 그래프 제목 설정
)

# 축 라벨 설정
plt.xlabel('KRW 환산급여', fontsize=14)  # x축 라벨과 글꼴 크기 설정
plt.ylabel('빈도수', fontsize=14)  # y축 라벨과 글꼴 크기 설정

# 그리드와 스타일 설정
plt.grid(True, linestyle='--', alpha=0.7)  # 그리드 설정 (점선 스타일, 투명도 0.7)
plt.gca().set_axisbelow(True)  # 그리드를 데이터 뒤에 배치

# 눈금 매개변수 설정
plt.tick_params(axis='both', which='major', labelsize=12)  # 눈금 라벨 크기 설정

# 배경 색상 추가
plt.gca().set_facecolor('#F5F5F5')  # 배경 색상 설정

# 그래프 표시
plt.show()  # 그래프 출력

# %%
# 'KRW환산급여'에 대한 히스토그램을 1억원 단위로 구분하여 생성
bin_edges = range(0, int(data['KRW환산급여'].max()) + 100000000, 100000000)  # 1억원 단위로 구간 설정

data['KRW환산급여'].plot.hist(
    figsize=(12, 8),  # 그래프 크기 설정 (가로 12인치, 세로 8인치)
    bins=bin_edges,  # 설정한 구간 적용
    color='#66B2FF',  # 막대 색상 설정
    edgecolor='black',  # 막대 테두리 색상 설정
    alpha=0.7,  # 막대 투명도 설정
    title='KRW 환산급여 분포'  # 그래프 제목 설정
)

# 축 라벨 설정
plt.xlabel('KRW 환산급여', fontsize=14)  # x축 라벨과 글꼴 크기 설정
plt.ylabel('빈도수', fontsize=14)  # y축 라벨과 글꼴 크기 설정

# 그리드와 스타일 설정
plt.grid(True, linestyle='--', alpha=0.7)  # 그리드 설정 (점선 스타일, 투명도 0.7)
plt.gca().set_axisbelow(True)  # 그리드를 데이터 뒤에 배치

# 눈금 매개변수 설정
plt.tick_params(axis='both', which='major', labelsize=12)  # 눈금 라벨 크기 설정

# 배경 색상 추가
plt.gca().set_facecolor('#F5F5F5')  # 배경 색상 설정

# 그래프 표시
plt.show()  # 그래프 출력

# %% [markdown]
# # 6.bar plot

# %%
level_mean = data.groupby("경험수준_한글").KRW환산급여.mean()
level_mean
# Out:
# 경험수준_한글
# 신입    1.086366e+08
# 중간    1.445688e+08
# 고위    2.116834e+08
# 임원    2.696070e+08
# Name: KRW환산급여, dtype: float64

# %%
level_mean.plot.bar()
# Out:
# <Axes: xlabel='경험수준_한글'>

# %%
# 막대 그래프로 시각화
level_mean.plot.bar(
    figsize=(12, 8),  # 그래프 크기 설정 (가로 12인치, 세로 8인치)
    color='#66B2FF',  # 막대 색상 설정
    edgecolor='black',  # 막대 테두리 색상 설정
    alpha=0.7,  # 막대 투명도 설정
    title='경험수준별 평균 KRW 환산급여'  # 그래프 제목 설정
)

# 축 라벨 설정
plt.xlabel('경험수준', fontsize=14)  # x축 라벨과 글꼴 크기 설정
plt.ylabel('평균 KRW 환산급여', fontsize=14)  # y축 라벨과 글꼴 크기 설정

# 그리드와 스타일 설정
plt.grid(True, linestyle='--', alpha=0.7)  # 그리드 설정 (점선 스타일, 투명도 0.7)
plt.gca().set_axisbelow(True)  # 그리드를 데이터 뒤에 배치

# 눈금 매개변수 설정
plt.tick_params(axis='both', which='major', labelsize=12)  # 눈금 라벨 크기 설정

# 배경 색상 추가
plt.gca().set_facecolor('#F5F5F5')  # 배경 색상 설정

# 그래프 표시
plt.show()  # 그래프 출력

# %%
# 막대 그래프로 시각화
plt.figure(figsize=(12, 8))
bars = plt.bar(
    level_mean.index,  # x축 값
    level_mean.values,  # y축 값
    color=['#FF9999', '#66B2FF', '#99FF99', '#FFCC99'],  # 막대 색상
    edgecolor='black',  # 막대 테두리 색상
    alpha=0.85  # 막대 투명도
)

# 막대 위에 값을 표시
for bar in bars:
    yval = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        yval,
        f'{yval:,.0f} KRW',
        ha='center',
        va='bottom',
        fontsize=12,
        fontweight='bold'
    )

# 축 라벨과 제목 설정
plt.title('경험수준별 평균 KRW 환산급여', fontsize=18, fontweight='bold')
plt.xlabel('경험수준', fontsize=16)
plt.ylabel('평균 KRW 환산급여', fontsize=16)

# 그리드와 스타일 설정
plt.grid(True, linestyle='--', alpha=0.7)
plt.gca().set_axisbelow(True)

# 눈금 매개변수 설정
plt.tick_params(axis='both', which='major', labelsize=14)

# 배경 색상 추가
plt.gca().set_facecolor('#F5F5F5')

# 그래프 표시
plt.show()

# %%
pivot = data.pivot_table(
    values="KRW환산급여",
    index="경험수준_한글",
    columns="근무연도",
    aggfunc="mean"
)
pivot
# Out:
# 근무연도             2020          2021          2022          2023
# 경험수준_한글
# 신입       7.954373e+07  7.593891e+07  1.065063e+08  1.317863e+08
# 중간       1.211099e+08  1.135751e+08  1.401148e+08  1.608500e+08
# 고위       1.898160e+08  1.743874e+08  2.042266e+08  2.206982e+08
# 임원       1.935556e+08  2.574318e+08  2.603809e+08  2.817433e+08

# %%
pivot.plot.barh()
# Out:
# <Axes: ylabel='경험수준_한글'>

# %%
# 수평 막대 그래프 그리기
pivot.plot.barh(
    figsize=(12, 8),  # 그래프 크기 설정 (가로 12인치, 세로 8인치)
    alpha=0.75,  # 막대 투명도 설정
    edgecolor='black'  # 막대 테두리 색상 설정
)

# 축 라벨과 제목 설정
plt.title('근무연도별 경험수준별 평균 KRW 환산급여', fontsize=18, fontweight='bold')  # 제목과 글꼴 설정
plt.xlabel('평균 KRW 환산급여 (억 단위)', fontsize=16)  # x축 라벨과 글꼴 설정
plt.ylabel('경험수준', fontsize=16)  # y축 라벨과 글꼴 설정

# 그리드와 스타일 설정
plt.grid(True, linestyle='--', alpha=0.7)  # 그리드 설정 (점선 스타일, 투명도 0.7)
plt.gca().set_axisbelow(True)  # 그리드를 데이터 뒤에 배치

# 눈금 매개변수 설정
plt.tick_params(axis='both', which='major', labelsize=14)  # 눈금 라벨 크기 설정

# 배경 색상 추가
plt.gca().set_facecolor('#F5F5F5')  # 배경 색상 설정

# 막대 위에 값을 억 단위로 표시
for container in plt.gca().containers:  # 각 막대에 대해
    labels = [f'{(value / 1e8):.2f}억' for value in container.datavalues]  # 값을 억 단위로 변환하여 라벨 생성
    plt.gca().bar_label(container, labels=labels, label_type='edge', fontsize=12, fontweight='bold')  # 라벨 추가

# 그래프 표시
plt.show()  # 그래프 출력

# %%
pivot = data.pivot_table(
    values="KRW환산급여",
    index="근무연도",
    columns="경험수준_한글",
    aggfunc="mean"
)
pivot
# Out:
# 경험수준_한글            신입            중간            고위            임원
# 근무연도
# 2020     7.954373e+07  1.211099e+08  1.898160e+08  1.935556e+08
# 2021     7.593891e+07  1.135751e+08  1.743874e+08  2.574318e+08
# 2022     1.065063e+08  1.401148e+08  2.042266e+08  2.603809e+08
# 2023     1.317863e+08  1.608500e+08  2.206982e+08  2.817433e+08

# %%
pivot.plot.barh(stacked=True)
# Out:
# <Axes: ylabel='근무연도'>

# %%
# 스택형 수평 막대 그래프 그리기
pivot.plot.barh(
    figsize=(12, 8),  # 그래프 크기 설정 (가로 12인치, 세로 8인치)
    alpha=0.75,  # 막대 투명도 설정
    edgecolor='black',  # 막대 테두리 색상 설정
    stacked=True  # 스택형 그래프로 설정
)

# 축 라벨과 제목 설정
plt.title('근무연도별 경험수준별 평균 KRW 환산급여', fontsize=18, fontweight='bold')  # 제목과 글꼴 설정
plt.xlabel('평균 KRW 환산급여 (억 단위)', fontsize=16)  # x축 라벨과 글꼴 설정
plt.ylabel('근무연도', fontsize=16)  # y축 라벨과 글꼴 설정

# 그리드와 스타일 설정
plt.grid(True, linestyle='--', alpha=0.7)  # 그리드 설정 (점선 스타일, 투명도 0.7)
plt.gca().set_axisbelow(True)  # 그리드를 데이터 뒤에 배치

# 눈금 매개변수 설정
plt.tick_params(axis='both', which='major', labelsize=14)  # 눈금 라벨 크기 설정

# 배경 색상 추가
plt.gca().set_facecolor('#F5F5F5')  # 배경 색상 설정

# 그래프 표시
plt.show()  # 그래프 출력

# %%
# 각 연도별로 경험수준_한글의 비중 계산
pivot_percentage = pivot.div(pivot.sum(axis=1), axis=0) * 100
pivot_percentage
# Out:
# 경험수준_한글         신입         중간         고위         임원
# 근무연도
# 2020     13.619914  20.737100  32.501332  33.141654
# 2021     12.221930  18.279260  28.066647  41.432162
# 2022     14.974969  19.700384  28.714627  36.610020
# 2023     16.575271  20.230729  27.758061  35.435939

# %%
# 스택형 수평 막대 그래프 그리기
ax = pivot.plot.barh(
    figsize=(12, 8),  # 그래프 크기 설정 (가로 12인치, 세로 8인치)
    alpha=0.75,  # 막대 투명도 설정
    edgecolor='black',  # 막대 테두리 색상 설정
    stacked=True  # 스택형 그래프로 설정
)

# 축 라벨과 제목 설정
plt.title('근무연도별 경험수준별 평균 KRW 환산급여', fontsize=18, fontweight='bold')  # 제목과 글꼴 설정
plt.xlabel('평균 KRW 환산급여 (억 단위)', fontsize=16)  # x축 라벨과 글꼴 설정
plt.ylabel('근무연도', fontsize=16)  # y축 라벨과 글꼴 설정

# 그리드와 스타일 설정
plt.grid(True, linestyle='--', alpha=0.7)  # 그리드 설정 (점선 스타일, 투명도 0.7)
plt.gca().set_axisbelow(True)  # 그리드를 데이터 뒤에 배치

# 눈금 매개변수 설정
plt.tick_params(axis='both', which='major', labelsize=14)  # 눈금 라벨 크기 설정

# 배경 색상 추가
plt.gca().set_facecolor('#F5F5F5')  # 배경 색상 설정

# 각 연도별로 경험수준_한글의 비중을 계산하여 막대 위에 텍스트로 추가
for container in ax.containers:
    labels = [f'{v:.1f}%' for v in pivot_percentage[container.get_label()]]
    ax.bar_label(container, labels=labels, label_type='center', fontsize=12, fontweight='bold', color='black')

# 그래프 표시
plt.show()  # 그래프 출력

# %% [markdown]
# # 7.line plot

# %%
year_mean = data.groupby("근무연도").KRW환산급여.mean()
year_mean
# Out:
# 근무연도
# 2020    1.276628e+08
# 2021    1.301311e+08
# 2022    1.844193e+08
# 2023    2.061434e+08
# Name: KRW환산급여, dtype: float64

# %%
year_mean.plot.line()
# Out:
# <Axes: xlabel='근무연도'>

# %%
# 라인 그래프로 시각화
year_mean.plot.line(
    figsize=(12, 8),  # 그래프 크기 설정 (가로 12인치, 세로 8인치)
    color='#66B2FF',  # 선 색상 설정
    linewidth=2,  # 선 두께 설정
    marker='o',  # 데이터 포인트 마커 설정
    title='근무연도별 평균 KRW 환산급여'  # 그래프 제목 설정
)

# 축 라벨 설정
plt.xlabel('근무연도', fontsize=14)  # x축 라벨과 글꼴 크기 설정
plt.ylabel('평균 KRW 환산급여', fontsize=14)  # y축 라벨과 글꼴 크기 설정

# 그리드와 스타일 설정
plt.grid(True, linestyle='--', alpha=0.7)  # 그리드 설정 (점선 스타일, 투명도 0.7)
plt.gca().set_axisbelow(True)  # 그리드를 데이터 뒤에 배치

# x축 틱 설정
plt.xticks(year_mean.index, rotation=45)

# 배경 색상 추가
plt.gca().set_facecolor('#F5F5F5')  # 배경 색상 설정

# 그래프 표시
plt.show()  # 그래프 출력

# %%
import numpy as np

# 근무연도별 평균 KRW 환산급여 계산
year_mean = data.groupby("근무연도").KRW환산급여.mean()

# 회귀선을 위한 다항식 피팅 (1차원, 선형 회귀)
z = np.polyfit(year_mean.index, year_mean, 1)
p = np.poly1d(z)

# %%
# 라인 그래프로 시각화
plt.figure(figsize=(12, 8))
plt.plot(year_mean.index, year_mean, 'o-', color='#66B2FF', linewidth=2, markersize=8, label='평균 KRW 환산급여')

# 추세선 추가
plt.plot(year_mean.index, p(year_mean.index), "r--", label='추세선')

# 축 라벨과 제목 설정
plt.title('근무연도별 평균 KRW 환산급여', fontsize=18, fontweight='bold')
plt.xlabel('근무연도', fontsize=14)
plt.ylabel('평균 KRW 환산급여', fontsize=14)

# 그리드와 스타일 설정
plt.grid(True, linestyle='--', alpha=0.7)
plt.gca().set_axisbelow(True)

# 배경 색상 추가
plt.gca().set_facecolor('#F5F5F5')

# x축 틱 설정
plt.xticks(year_mean.index, rotation=45)

# 범례 추가
plt.legend()

# 그래프 표시
plt.show()  # 그래프 출력

# %% [markdown]
# # 8.pie plot

# %%
year_mean.plot.pie()
# Out:
# <Axes: ylabel='KRW환산급여'>

# %%
# 파이 차트로 시각화
plt.figure(figsize=(12, 8))
year_mean.plot.pie(
    autopct='%1.1f%%',  # 각 섹션의 비율 표시 형식
    startangle=90,  # 파이 차트 시작 각도
    colors=plt.cm.Paired(np.arange(len(year_mean)))  # 색상 설정
)

# 제목 설정
plt.title('근무연도별 평균 KRW 환산급여 분포', fontsize=18, fontweight='bold')

# 파이 차트 표시
plt.ylabel('')  # y축 라벨 제거
plt.show()  # 그래프 출력

# %%
# 파이 차트로 시각화
fig, ax = plt.subplots(figsize=(12, 8))
year_mean.plot.pie(
    autopct='%1.1f%%',  # 각 섹션의 비율 표시 형식
    startangle=90,  # 파이 차트 시작 각도
    colors=plt.cm.Paired(np.arange(len(year_mean))),  # 색상 설정
    ax=ax
)

# 중앙의 원을 추가하여 도넛 차트로 만듭니다.
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig.gca().add_artist(centre_circle)

# 제목 설정
plt.title('근무연도별 평균 KRW 환산급여 분포', fontsize=18, fontweight='bold')

# 파이 차트 표시
plt.ylabel('')  # y축 라벨 제거
plt.show()  # 그래프 출력

# %% [markdown]
# # 9.style

# %%
pivot = data.pivot_table(
    values="KRW환산급여",
    index="근무연도",
    columns="경험수준_한글",
    aggfunc="mean"
)
pivot
# Out:
# 경험수준_한글            신입            중간            고위            임원
# 근무연도
# 2020     7.954373e+07  1.211099e+08  1.898160e+08  1.935556e+08
# 2021     7.593891e+07  1.135751e+08  1.743874e+08  2.574318e+08
# 2022     1.065063e+08  1.401148e+08  2.042266e+08  2.603809e+08
# 2023     1.317863e+08  1.608500e+08  2.206982e+08  2.817433e+08

# %% [markdown]
# ## 9.1. bar

# %%
pivot = data.pivot_table(
    values="KRW환산급여",
    index="경험수준_한글",
    columns="근무연도",
    aggfunc="mean"
)
pivot
# Out:
# 근무연도             2020          2021          2022          2023
# 경험수준_한글
# 신입       7.954373e+07  7.593891e+07  1.065063e+08  1.317863e+08
# 중간       1.211099e+08  1.135751e+08  1.401148e+08  1.608500e+08
# 고위       1.898160e+08  1.743874e+08  2.042266e+08  2.206982e+08
# 임원       1.935556e+08  2.574318e+08  2.603809e+08  2.817433e+08

# %%
pivot.style.bar()
# Out:
# <style type="text/css">
# #T_12da9_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 41.1%, transparent 41.1%);
# }
# #T_12da9_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 29.5%, transparent 29.5%);
# }
# #T_12da9_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 40.9%, transparent 40.9%);
# }
# #T_12da9_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 46.8%, transparent 46.8%);
# }
# #T_12da9_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 62.6%, transparent 62.6%);
# }
# #T_12da9_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 44.1%, transparent 44.1%);
# }
# #T_12da9_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 53.8%, transparent 53.8%);
# }
# #T_12da9_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 57.1%, transparent 57.1%);
# }
# #T_12da9_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.1%, transparent 98.1%);
# }
# #T_12da9_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 67.7%, transparent 67.7%);
# }
# #T_12da9_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 78.4%, transparent 78.4%);
# }
# #T_12da9_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 78.3%, transparent 78.3%);
# }
# #T_12da9_row3_col0, #T_12da9_row3_col1, #T_12da9_row3_col2, #T_12da9_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_12da9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_12da9_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_12da9_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_12da9_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_12da9_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12da9_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_12da9_row0_col0" class="data row0 col0" >79543730.870870</td>
#       <td id="T_12da9_row0_col1" class="data row0 col1" >75938908.509273</td>
#       <td id="T_12da9_row0_col2" class="data row0 col2" >106506262.001855</td>
#       <td id="T_12da9_row0_col3" class="data row0 col3" >131786300.675593</td>
#     </tr>
#     <tr>
#       <th id="T_12da9_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_12da9_row1_col0" class="data row1 col0" >121109886.855937</td>
#       <td id="T_12da9_row1_col1" class="data row1 col1" >113575111.328478</td>
#       <td id="T_12da9_row1_col2" class="data row1 col2" >140114760.005235</td>
#       <td id="T_12da9_row1_col3" class="data row1 col3" >160850043.261844</td>
#     </tr>
#     <tr>
#       <th id="T_12da9_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_12da9_row2_col0" class="data row2 col0" >189815963.145000</td>
#       <td id="T_12da9_row2_col1" class="data row2 col1" >174387395.257397</td>
#       <td id="T_12da9_row2_col2" class="data row2 col2" >204226637.943981</td>
#       <td id="T_12da9_row2_col3" class="data row2 col3" >220698189.341096</td>
#     </tr>
#     <tr>
#       <th id="T_12da9_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_12da9_row3_col0" class="data row3 col0" >193555607.990000</td>
#       <td id="T_12da9_row3_col1" class="data row3 col1" >257431775.520000</td>
#       <td id="T_12da9_row3_col2" class="data row3 col2" >260380928.206829</td>
#       <td id="T_12da9_row3_col3" class="data row3 col3" >281743293.561500</td>
#     </tr>
#   </tbody>
# </table>

# %%
# subset 원하는 컬럼만 스타일 적용하기
pivot.style.bar(subset=[2022, 2023])
# Out:
# <style type="text/css">
# #T_9adea_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 40.9%, transparent 40.9%);
# }
# #T_9adea_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 46.8%, transparent 46.8%);
# }
# #T_9adea_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 53.8%, transparent 53.8%);
# }
# #T_9adea_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 57.1%, transparent 57.1%);
# }
# #T_9adea_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 78.4%, transparent 78.4%);
# }
# #T_9adea_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 78.3%, transparent 78.3%);
# }
# #T_9adea_row3_col2, #T_9adea_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_9adea" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_9adea_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_9adea_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_9adea_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_9adea_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9adea_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_9adea_row0_col0" class="data row0 col0" >79543730.870870</td>
#       <td id="T_9adea_row0_col1" class="data row0 col1" >75938908.509273</td>
#       <td id="T_9adea_row0_col2" class="data row0 col2" >106506262.001855</td>
#       <td id="T_9adea_row0_col3" class="data row0 col3" >131786300.675593</td>
#     </tr>
#     <tr>
#       <th id="T_9adea_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_9adea_row1_col0" class="data row1 col0" >121109886.855937</td>
#       <td id="T_9adea_row1_col1" class="data row1 col1" >113575111.328478</td>
#       <td id="T_9adea_row1_col2" class="data row1 col2" >140114760.005235</td>
#       <td id="T_9adea_row1_col3" class="data row1 col3" >160850043.261844</td>
#     </tr>
#     <tr>
#       <th id="T_9adea_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_9adea_row2_col0" class="data row2 col0" >189815963.145000</td>
#       <td id="T_9adea_row2_col1" class="data row2 col1" >174387395.257397</td>
#       <td id="T_9adea_row2_col2" class="data row2 col2" >204226637.943981</td>
#       <td id="T_9adea_row2_col3" class="data row2 col3" >220698189.341096</td>
#     </tr>
#     <tr>
#       <th id="T_9adea_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_9adea_row3_col0" class="data row3 col0" >193555607.990000</td>
#       <td id="T_9adea_row3_col1" class="data row3 col1" >257431775.520000</td>
#       <td id="T_9adea_row3_col2" class="data row3 col2" >260380928.206829</td>
#       <td id="T_9adea_row3_col3" class="data row3 col3" >281743293.561500</td>
#     </tr>
#   </tbody>
# </table>

# %%
# https://www.kaggle.com/code/subinium/simple-matplotlib-visualization-tips
def cmap_plot(cmap_list):
    cmaps = cmap_list

    n = len(cmaps)

    fig = plt.figure(figsize=(8.25, n*.20), dpi=200)
    ax = plt.subplot(1, 1, 1, frameon=False, xlim=[0,10], xticks=[], yticks=[])
    fig.subplots_adjust(top=0.99, bottom=0.01, left=0.18, right=0.99)

    y, dy, pad = 0, 0.3, 0.08

    ticks, labels = [], []

    for cmap in cmaps[::-1]:
        Z = np.linspace(0,1,512).reshape(1,512)
        plt.imshow(Z, extent=[0,10,y,y+dy], cmap=plt.get_cmap(cmap))
        ticks.append(y+dy/2)
        labels.append(cmap)
        y = y + dy + pad

    ax.set_ylim(-pad,y)
    ax.set_yticks(ticks)
    ax.set_yticklabels(labels)

    ax.tick_params(axis='y', which='both', length=0, labelsize=5)
    plt.show()

# %%
# 모든 colormap 이름을 가져오기
cmaps = plt.colormaps()
cmap_plot(cmaps)

# %%
# cmap 컬러맵 바꾸기
pivot.style.bar(subset=[2022, 2023], cmap="Blues")
# Out:
# <style type="text/css">
# #T_066ee_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #91c3de 40.9%, transparent 40.9%);
# }
# #T_066ee_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #79b5d9 46.8%, transparent 46.8%);
# }
# #T_066ee_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fa6d1 53.8%, transparent 53.8%);
# }
# #T_066ee_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #539ecd 57.1%, transparent 57.1%);
# }
# #T_066ee_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #1a68ae 78.4%, transparent 78.4%);
# }
# #T_066ee_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #1a68ae 78.3%, transparent 78.3%);
# }
# #T_066ee_row3_col2, #T_066ee_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #08306b 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_066ee" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_066ee_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_066ee_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_066ee_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_066ee_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_066ee_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_066ee_row0_col0" class="data row0 col0" >79543730.870870</td>
#       <td id="T_066ee_row0_col1" class="data row0 col1" >75938908.509273</td>
#       <td id="T_066ee_row0_col2" class="data row0 col2" >106506262.001855</td>
#       <td id="T_066ee_row0_col3" class="data row0 col3" >131786300.675593</td>
#     </tr>
#     <tr>
#       <th id="T_066ee_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_066ee_row1_col0" class="data row1 col0" >121109886.855937</td>
#       <td id="T_066ee_row1_col1" class="data row1 col1" >113575111.328478</td>
#       <td id="T_066ee_row1_col2" class="data row1 col2" >140114760.005235</td>
#       <td id="T_066ee_row1_col3" class="data row1 col3" >160850043.261844</td>
#     </tr>
#     <tr>
#       <th id="T_066ee_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_066ee_row2_col0" class="data row2 col0" >189815963.145000</td>
#       <td id="T_066ee_row2_col1" class="data row2 col1" >174387395.257397</td>
#       <td id="T_066ee_row2_col2" class="data row2 col2" >204226637.943981</td>
#       <td id="T_066ee_row2_col3" class="data row2 col3" >220698189.341096</td>
#     </tr>
#     <tr>
#       <th id="T_066ee_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_066ee_row3_col0" class="data row3 col0" >193555607.990000</td>
#       <td id="T_066ee_row3_col1" class="data row3 col1" >257431775.520000</td>
#       <td id="T_066ee_row3_col2" class="data row3 col2" >260380928.206829</td>
#       <td id="T_066ee_row3_col3" class="data row3 col3" >281743293.561500</td>
#     </tr>
#   </tbody>
# </table>

# %%
# props 테이블 속성 바꾸기
pivot.style.bar(subset=[2022, 2023], cmap="Blues", props="width: 300px;")
# Out:
# <style type="text/css">
# #T_59733_row0_col2 {
#   width: 300px;
#   background: linear-gradient(90deg, #91c3de 40.9%, transparent 40.9%);
# }
# #T_59733_row0_col3 {
#   width: 300px;
#   background: linear-gradient(90deg, #79b5d9 46.8%, transparent 46.8%);
# }
# #T_59733_row1_col2 {
#   width: 300px;
#   background: linear-gradient(90deg, #5fa6d1 53.8%, transparent 53.8%);
# }
# #T_59733_row1_col3 {
#   width: 300px;
#   background: linear-gradient(90deg, #539ecd 57.1%, transparent 57.1%);
# }
# #T_59733_row2_col2 {
#   width: 300px;
#   background: linear-gradient(90deg, #1a68ae 78.4%, transparent 78.4%);
# }
# #T_59733_row2_col3 {
#   width: 300px;
#   background: linear-gradient(90deg, #1a68ae 78.3%, transparent 78.3%);
# }
# #T_59733_row3_col2, #T_59733_row3_col3 {
#   width: 300px;
#   background: linear-gradient(90deg, #08306b 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_59733" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_59733_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_59733_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_59733_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_59733_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59733_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_59733_row0_col0" class="data row0 col0" >79543730.870870</td>
#       <td id="T_59733_row0_col1" class="data row0 col1" >75938908.509273</td>
#       <td id="T_59733_row0_col2" class="data row0 col2" >106506262.001855</td>
#       <td id="T_59733_row0_col3" class="data row0 col3" >131786300.675593</td>
#     </tr>
#     <tr>
#       <th id="T_59733_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_59733_row1_col0" class="data row1 col0" >121109886.855937</td>
#       <td id="T_59733_row1_col1" class="data row1 col1" >113575111.328478</td>
#       <td id="T_59733_row1_col2" class="data row1 col2" >140114760.005235</td>
#       <td id="T_59733_row1_col3" class="data row1 col3" >160850043.261844</td>
#     </tr>
#     <tr>
#       <th id="T_59733_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_59733_row2_col0" class="data row2 col0" >189815963.145000</td>
#       <td id="T_59733_row2_col1" class="data row2 col1" >174387395.257397</td>
#       <td id="T_59733_row2_col2" class="data row2 col2" >204226637.943981</td>
#       <td id="T_59733_row2_col3" class="data row2 col3" >220698189.341096</td>
#     </tr>
#     <tr>
#       <th id="T_59733_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_59733_row3_col0" class="data row3 col0" >193555607.990000</td>
#       <td id="T_59733_row3_col1" class="data row3 col1" >257431775.520000</td>
#       <td id="T_59733_row3_col2" class="data row3 col2" >260380928.206829</td>
#       <td id="T_59733_row3_col3" class="data row3 col3" >281743293.561500</td>
#     </tr>
#   </tbody>
# </table>

# %%
# props 테이블 속성 바꾸기
pivot.style.bar(subset=[2022, 2023], cmap="Blues", props="width: 300px;", vmin=0, vmax=500000000)
# Out:
# <style type="text/css">
# #T_4dec3_row0_col2 {
#   width: 300px;
#   background: linear-gradient(90deg, #cde0f1 21.3%, transparent 21.3%);
# }
# #T_4dec3_row0_col3 {
#   width: 300px;
#   background: linear-gradient(90deg, #c2d9ee 26.4%, transparent 26.4%);
# }
# #T_4dec3_row1_col2 {
#   width: 300px;
#   background: linear-gradient(90deg, #bdd7ec 28.0%, transparent 28.0%);
# }
# #T_4dec3_row1_col3 {
#   width: 300px;
#   background: linear-gradient(90deg, #afd1e7 32.2%, transparent 32.2%);
# }
# #T_4dec3_row2_col2 {
#   width: 300px;
#   background: linear-gradient(90deg, #91c3de 40.8%, transparent 40.8%);
# }
# #T_4dec3_row2_col3 {
#   width: 300px;
#   background: linear-gradient(90deg, #84bcdb 44.1%, transparent 44.1%);
# }
# #T_4dec3_row3_col2 {
#   width: 300px;
#   background: linear-gradient(90deg, #64a9d3 52.1%, transparent 52.1%);
# }
# #T_4dec3_row3_col3 {
#   width: 300px;
#   background: linear-gradient(90deg, #56a0ce 56.3%, transparent 56.3%);
# }
# </style>
# <table id="T_4dec3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_4dec3_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_4dec3_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_4dec3_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_4dec3_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4dec3_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_4dec3_row0_col0" class="data row0 col0" >79543730.870870</td>
#       <td id="T_4dec3_row0_col1" class="data row0 col1" >75938908.509273</td>
#       <td id="T_4dec3_row0_col2" class="data row0 col2" >106506262.001855</td>
#       <td id="T_4dec3_row0_col3" class="data row0 col3" >131786300.675593</td>
#     </tr>
#     <tr>
#       <th id="T_4dec3_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_4dec3_row1_col0" class="data row1 col0" >121109886.855937</td>
#       <td id="T_4dec3_row1_col1" class="data row1 col1" >113575111.328478</td>
#       <td id="T_4dec3_row1_col2" class="data row1 col2" >140114760.005235</td>
#       <td id="T_4dec3_row1_col3" class="data row1 col3" >160850043.261844</td>
#     </tr>
#     <tr>
#       <th id="T_4dec3_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_4dec3_row2_col0" class="data row2 col0" >189815963.145000</td>
#       <td id="T_4dec3_row2_col1" class="data row2 col1" >174387395.257397</td>
#       <td id="T_4dec3_row2_col2" class="data row2 col2" >204226637.943981</td>
#       <td id="T_4dec3_row2_col3" class="data row2 col3" >220698189.341096</td>
#     </tr>
#     <tr>
#       <th id="T_4dec3_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_4dec3_row3_col0" class="data row3 col0" >193555607.990000</td>
#       <td id="T_4dec3_row3_col1" class="data row3 col1" >257431775.520000</td>
#       <td id="T_4dec3_row3_col2" class="data row3 col2" >260380928.206829</td>
#       <td id="T_4dec3_row3_col3" class="data row3 col3" >281743293.561500</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 변수로서 할당받아 각 컬럼마다 다른 스타일 적용
s = pivot.style
s.bar(subset=[2020])
s.bar(subset=[2021], cmap="Blues")
s.bar(subset=[2022], cmap="Blues", props="width: 300px;")
s.bar(subset=[2023], cmap="Blues", props="width: 300px;", vmin=0, vmax=500000000)
s
# Out:
# <style type="text/css">
# #T_b5162_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 41.1%, transparent 41.1%);
# }
# #T_b5162_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b8d5ea 29.5%, transparent 29.5%);
# }
# #T_b5162_row0_col2 {
#   width: 300px;
#   background: linear-gradient(90deg, #91c3de 40.9%, transparent 40.9%);
# }
# #T_b5162_row0_col3 {
#   width: 300px;
#   background: linear-gradient(90deg, #c2d9ee 26.4%, transparent 26.4%);
# }
# #T_b5162_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 62.6%, transparent 62.6%);
# }
# #T_b5162_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #84bcdb 44.1%, transparent 44.1%);
# }
# #T_b5162_row1_col2 {
#   width: 300px;
#   background: linear-gradient(90deg, #5fa6d1 53.8%, transparent 53.8%);
# }
# #T_b5162_row1_col3 {
#   width: 300px;
#   background: linear-gradient(90deg, #afd1e7 32.2%, transparent 32.2%);
# }
# #T_b5162_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.1%, transparent 98.1%);
# }
# #T_b5162_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #3484bf 67.7%, transparent 67.7%);
# }
# #T_b5162_row2_col2 {
#   width: 300px;
#   background: linear-gradient(90deg, #1a68ae 78.4%, transparent 78.4%);
# }
# #T_b5162_row2_col3 {
#   width: 300px;
#   background: linear-gradient(90deg, #84bcdb 44.1%, transparent 44.1%);
# }
# #T_b5162_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_b5162_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #08306b 100.0%, transparent 100.0%);
# }
# #T_b5162_row3_col2 {
#   width: 300px;
#   background: linear-gradient(90deg, #08306b 100.0%, transparent 100.0%);
# }
# #T_b5162_row3_col3 {
#   width: 300px;
#   background: linear-gradient(90deg, #56a0ce 56.3%, transparent 56.3%);
# }
# </style>
# <table id="T_b5162" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_b5162_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_b5162_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_b5162_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_b5162_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5162_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_b5162_row0_col0" class="data row0 col0" >79543730.870870</td>
#       <td id="T_b5162_row0_col1" class="data row0 col1" >75938908.509273</td>
#       <td id="T_b5162_row0_col2" class="data row0 col2" >106506262.001855</td>
#       <td id="T_b5162_row0_col3" class="data row0 col3" >131786300.675593</td>
#     </tr>
#     <tr>
#       <th id="T_b5162_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_b5162_row1_col0" class="data row1 col0" >121109886.855937</td>
#       <td id="T_b5162_row1_col1" class="data row1 col1" >113575111.328478</td>
#       <td id="T_b5162_row1_col2" class="data row1 col2" >140114760.005235</td>
#       <td id="T_b5162_row1_col3" class="data row1 col3" >160850043.261844</td>
#     </tr>
#     <tr>
#       <th id="T_b5162_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_b5162_row2_col0" class="data row2 col0" >189815963.145000</td>
#       <td id="T_b5162_row2_col1" class="data row2 col1" >174387395.257397</td>
#       <td id="T_b5162_row2_col2" class="data row2 col2" >204226637.943981</td>
#       <td id="T_b5162_row2_col3" class="data row2 col3" >220698189.341096</td>
#     </tr>
#     <tr>
#       <th id="T_b5162_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_b5162_row3_col0" class="data row3 col0" >193555607.990000</td>
#       <td id="T_b5162_row3_col1" class="data row3 col1" >257431775.520000</td>
#       <td id="T_b5162_row3_col2" class="data row3 col2" >260380928.206829</td>
#       <td id="T_b5162_row3_col3" class="data row3 col3" >281743293.561500</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 9.2. format

# %%
pivot
# Out:
# 근무연도             2020          2021          2022          2023
# 경험수준_한글
# 신입       7.954373e+07  7.593891e+07  1.065063e+08  1.317863e+08
# 중간       1.211099e+08  1.135751e+08  1.401148e+08  1.608500e+08
# 고위       1.898160e+08  1.743874e+08  2.042266e+08  2.206982e+08
# 임원       1.935556e+08  2.574318e+08  2.603809e+08  2.817433e+08

# %%
pivot.style.format(formatter="{:.1f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_945f2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_945f2_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_945f2_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_945f2_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_945f2_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_945f2_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_945f2_row0_col0" class="data row0 col0" >79543730.9</td>
#       <td id="T_945f2_row0_col1" class="data row0 col1" >75938908.5</td>
#       <td id="T_945f2_row0_col2" class="data row0 col2" >106506262.0</td>
#       <td id="T_945f2_row0_col3" class="data row0 col3" >131786300.7</td>
#     </tr>
#     <tr>
#       <th id="T_945f2_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_945f2_row1_col0" class="data row1 col0" >121109886.9</td>
#       <td id="T_945f2_row1_col1" class="data row1 col1" >113575111.3</td>
#       <td id="T_945f2_row1_col2" class="data row1 col2" >140114760.0</td>
#       <td id="T_945f2_row1_col3" class="data row1 col3" >160850043.3</td>
#     </tr>
#     <tr>
#       <th id="T_945f2_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_945f2_row2_col0" class="data row2 col0" >189815963.1</td>
#       <td id="T_945f2_row2_col1" class="data row2 col1" >174387395.3</td>
#       <td id="T_945f2_row2_col2" class="data row2 col2" >204226637.9</td>
#       <td id="T_945f2_row2_col3" class="data row2 col3" >220698189.3</td>
#     </tr>
#     <tr>
#       <th id="T_945f2_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_945f2_row3_col0" class="data row3 col0" >193555608.0</td>
#       <td id="T_945f2_row3_col1" class="data row3 col1" >257431775.5</td>
#       <td id="T_945f2_row3_col2" class="data row3 col2" >260380928.2</td>
#       <td id="T_945f2_row3_col3" class="data row3 col3" >281743293.6</td>
#     </tr>
#   </tbody>
# </table>

# %%
s = pivot.style
s = s.format(subset=[2020, 2021], formatter="{:.1f}")
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_62853" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_62853_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_62853_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_62853_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_62853_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62853_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_62853_row0_col0" class="data row0 col0" >79543730.9</td>
#       <td id="T_62853_row0_col1" class="data row0 col1" >75938908.5</td>
#       <td id="T_62853_row0_col2" class="data row0 col2" >106506262.001855</td>
#       <td id="T_62853_row0_col3" class="data row0 col3" >131786300.675593</td>
#     </tr>
#     <tr>
#       <th id="T_62853_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_62853_row1_col0" class="data row1 col0" >121109886.9</td>
#       <td id="T_62853_row1_col1" class="data row1 col1" >113575111.3</td>
#       <td id="T_62853_row1_col2" class="data row1 col2" >140114760.005235</td>
#       <td id="T_62853_row1_col3" class="data row1 col3" >160850043.261844</td>
#     </tr>
#     <tr>
#       <th id="T_62853_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_62853_row2_col0" class="data row2 col0" >189815963.1</td>
#       <td id="T_62853_row2_col1" class="data row2 col1" >174387395.3</td>
#       <td id="T_62853_row2_col2" class="data row2 col2" >204226637.943981</td>
#       <td id="T_62853_row2_col3" class="data row2 col3" >220698189.341096</td>
#     </tr>
#     <tr>
#       <th id="T_62853_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_62853_row3_col0" class="data row3 col0" >193555608.0</td>
#       <td id="T_62853_row3_col1" class="data row3 col1" >257431775.5</td>
#       <td id="T_62853_row3_col2" class="data row3 col2" >260380928.206829</td>
#       <td id="T_62853_row3_col3" class="data row3 col3" >281743293.561500</td>
#     </tr>
#   </tbody>
# </table>

# %%
s = pivot.style
s.format(subset=[2020])
s.format(subset=[2021], formatter="{:.0f}")
s.format(subset=[2022], formatter="{:.3f}")
s.format(subset=[2023], formatter="{:,.0f}")
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_eab6b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_eab6b_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_eab6b_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_eab6b_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_eab6b_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eab6b_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_eab6b_row0_col0" class="data row0 col0" >79543730.870870</td>
#       <td id="T_eab6b_row0_col1" class="data row0 col1" >75938909</td>
#       <td id="T_eab6b_row0_col2" class="data row0 col2" >106506262.002</td>
#       <td id="T_eab6b_row0_col3" class="data row0 col3" >131,786,301</td>
#     </tr>
#     <tr>
#       <th id="T_eab6b_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_eab6b_row1_col0" class="data row1 col0" >121109886.855937</td>
#       <td id="T_eab6b_row1_col1" class="data row1 col1" >113575111</td>
#       <td id="T_eab6b_row1_col2" class="data row1 col2" >140114760.005</td>
#       <td id="T_eab6b_row1_col3" class="data row1 col3" >160,850,043</td>
#     </tr>
#     <tr>
#       <th id="T_eab6b_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_eab6b_row2_col0" class="data row2 col0" >189815963.145000</td>
#       <td id="T_eab6b_row2_col1" class="data row2 col1" >174387395</td>
#       <td id="T_eab6b_row2_col2" class="data row2 col2" >204226637.944</td>
#       <td id="T_eab6b_row2_col3" class="data row2 col3" >220,698,189</td>
#     </tr>
#     <tr>
#       <th id="T_eab6b_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_eab6b_row3_col0" class="data row3 col0" >193555607.990000</td>
#       <td id="T_eab6b_row3_col1" class="data row3 col1" >257431776</td>
#       <td id="T_eab6b_row3_col2" class="data row3 col2" >260380928.207</td>
#       <td id="T_eab6b_row3_col3" class="data row3 col3" >281,743,294</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 9.3. background_gradient

# %%
pivot.style.background_gradient()
# Out:
# <style type="text/css">
# #T_f3dc9_row0_col0, #T_f3dc9_row0_col1, #T_f3dc9_row0_col2, #T_f3dc9_row0_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_f3dc9_row1_col0 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_f3dc9_row1_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_f3dc9_row1_col2 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_f3dc9_row1_col3 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_f3dc9_row2_col0 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_f3dc9_row2_col1 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_f3dc9_row2_col2 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_f3dc9_row2_col3 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_f3dc9_row3_col0, #T_f3dc9_row3_col1, #T_f3dc9_row3_col2, #T_f3dc9_row3_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f3dc9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_f3dc9_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_f3dc9_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_f3dc9_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_f3dc9_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3dc9_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_f3dc9_row0_col0" class="data row0 col0" >79543730.870870</td>
#       <td id="T_f3dc9_row0_col1" class="data row0 col1" >75938908.509273</td>
#       <td id="T_f3dc9_row0_col2" class="data row0 col2" >106506262.001855</td>
#       <td id="T_f3dc9_row0_col3" class="data row0 col3" >131786300.675593</td>
#     </tr>
#     <tr>
#       <th id="T_f3dc9_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_f3dc9_row1_col0" class="data row1 col0" >121109886.855937</td>
#       <td id="T_f3dc9_row1_col1" class="data row1 col1" >113575111.328478</td>
#       <td id="T_f3dc9_row1_col2" class="data row1 col2" >140114760.005235</td>
#       <td id="T_f3dc9_row1_col3" class="data row1 col3" >160850043.261844</td>
#     </tr>
#     <tr>
#       <th id="T_f3dc9_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_f3dc9_row2_col0" class="data row2 col0" >189815963.145000</td>
#       <td id="T_f3dc9_row2_col1" class="data row2 col1" >174387395.257397</td>
#       <td id="T_f3dc9_row2_col2" class="data row2 col2" >204226637.943981</td>
#       <td id="T_f3dc9_row2_col3" class="data row2 col3" >220698189.341096</td>
#     </tr>
#     <tr>
#       <th id="T_f3dc9_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_f3dc9_row3_col0" class="data row3 col0" >193555607.990000</td>
#       <td id="T_f3dc9_row3_col1" class="data row3 col1" >257431775.520000</td>
#       <td id="T_f3dc9_row3_col2" class="data row3 col2" >260380928.206829</td>
#       <td id="T_f3dc9_row3_col3" class="data row3 col3" >281743293.561500</td>
#     </tr>
#   </tbody>
# </table>

# %%
pivot.style.background_gradient(axis=1)
# Out:
# <style type="text/css">
# #T_ec7b7_row0_col0 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_ec7b7_row0_col1, #T_ec7b7_row1_col1, #T_ec7b7_row2_col1, #T_ec7b7_row3_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ec7b7_row0_col2 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_ec7b7_row0_col3, #T_ec7b7_row1_col3, #T_ec7b7_row2_col3, #T_ec7b7_row3_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ec7b7_row1_col0 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_ec7b7_row1_col2 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_ec7b7_row2_col0 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_ec7b7_row2_col2 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_ec7b7_row3_col1 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_ec7b7_row3_col2 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ec7b7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_ec7b7_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_ec7b7_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_ec7b7_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_ec7b7_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec7b7_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_ec7b7_row0_col0" class="data row0 col0" >79543730.870870</td>
#       <td id="T_ec7b7_row0_col1" class="data row0 col1" >75938908.509273</td>
#       <td id="T_ec7b7_row0_col2" class="data row0 col2" >106506262.001855</td>
#       <td id="T_ec7b7_row0_col3" class="data row0 col3" >131786300.675593</td>
#     </tr>
#     <tr>
#       <th id="T_ec7b7_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_ec7b7_row1_col0" class="data row1 col0" >121109886.855937</td>
#       <td id="T_ec7b7_row1_col1" class="data row1 col1" >113575111.328478</td>
#       <td id="T_ec7b7_row1_col2" class="data row1 col2" >140114760.005235</td>
#       <td id="T_ec7b7_row1_col3" class="data row1 col3" >160850043.261844</td>
#     </tr>
#     <tr>
#       <th id="T_ec7b7_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_ec7b7_row2_col0" class="data row2 col0" >189815963.145000</td>
#       <td id="T_ec7b7_row2_col1" class="data row2 col1" >174387395.257397</td>
#       <td id="T_ec7b7_row2_col2" class="data row2 col2" >204226637.943981</td>
#       <td id="T_ec7b7_row2_col3" class="data row2 col3" >220698189.341096</td>
#     </tr>
#     <tr>
#       <th id="T_ec7b7_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_ec7b7_row3_col0" class="data row3 col0" >193555607.990000</td>
#       <td id="T_ec7b7_row3_col1" class="data row3 col1" >257431775.520000</td>
#       <td id="T_ec7b7_row3_col2" class="data row3 col2" >260380928.206829</td>
#       <td id="T_ec7b7_row3_col3" class="data row3 col3" >281743293.561500</td>
#     </tr>
#   </tbody>
# </table>

# %%
pivot.style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_e755a_row0_col0, #T_e755a_row0_col1, #T_e755a_row0_col2, #T_e755a_row0_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e755a_row1_col0 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_e755a_row1_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_e755a_row1_col2 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_e755a_row1_col3 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_e755a_row2_col0 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_e755a_row2_col1 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_e755a_row2_col2 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_e755a_row2_col3 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_e755a_row3_col0, #T_e755a_row3_col1, #T_e755a_row3_col2, #T_e755a_row3_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e755a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_e755a_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_e755a_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_e755a_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_e755a_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e755a_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_e755a_row0_col0" class="data row0 col0" >79543730.870870</td>
#       <td id="T_e755a_row0_col1" class="data row0 col1" >75938908.509273</td>
#       <td id="T_e755a_row0_col2" class="data row0 col2" >106506262.001855</td>
#       <td id="T_e755a_row0_col3" class="data row0 col3" >131786300.675593</td>
#     </tr>
#     <tr>
#       <th id="T_e755a_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_e755a_row1_col0" class="data row1 col0" >121109886.855937</td>
#       <td id="T_e755a_row1_col1" class="data row1 col1" >113575111.328478</td>
#       <td id="T_e755a_row1_col2" class="data row1 col2" >140114760.005235</td>
#       <td id="T_e755a_row1_col3" class="data row1 col3" >160850043.261844</td>
#     </tr>
#     <tr>
#       <th id="T_e755a_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_e755a_row2_col0" class="data row2 col0" >189815963.145000</td>
#       <td id="T_e755a_row2_col1" class="data row2 col1" >174387395.257397</td>
#       <td id="T_e755a_row2_col2" class="data row2 col2" >204226637.943981</td>
#       <td id="T_e755a_row2_col3" class="data row2 col3" >220698189.341096</td>
#     </tr>
#     <tr>
#       <th id="T_e755a_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_e755a_row3_col0" class="data row3 col0" >193555607.990000</td>
#       <td id="T_e755a_row3_col1" class="data row3 col1" >257431775.520000</td>
#       <td id="T_e755a_row3_col2" class="data row3 col2" >260380928.206829</td>
#       <td id="T_e755a_row3_col3" class="data row3 col3" >281743293.561500</td>
#     </tr>
#   </tbody>
# </table>

# %%
pivot.style.background_gradient(axis=None)
# Out:
# <style type="text/css">
# #T_d599a_row0_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_d599a_row0_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d599a_row0_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_d599a_row0_col3 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_d599a_row1_col0 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_d599a_row1_col1 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_d599a_row1_col2 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_d599a_row1_col3 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_d599a_row2_col0 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_d599a_row2_col1 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_d599a_row2_col2 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_d599a_row2_col3 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_d599a_row3_col0 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_d599a_row3_col1 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_d599a_row3_col2 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_d599a_row3_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d599a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_d599a_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_d599a_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_d599a_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_d599a_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d599a_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_d599a_row0_col0" class="data row0 col0" >79543730.870870</td>
#       <td id="T_d599a_row0_col1" class="data row0 col1" >75938908.509273</td>
#       <td id="T_d599a_row0_col2" class="data row0 col2" >106506262.001855</td>
#       <td id="T_d599a_row0_col3" class="data row0 col3" >131786300.675593</td>
#     </tr>
#     <tr>
#       <th id="T_d599a_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_d599a_row1_col0" class="data row1 col0" >121109886.855937</td>
#       <td id="T_d599a_row1_col1" class="data row1 col1" >113575111.328478</td>
#       <td id="T_d599a_row1_col2" class="data row1 col2" >140114760.005235</td>
#       <td id="T_d599a_row1_col3" class="data row1 col3" >160850043.261844</td>
#     </tr>
#     <tr>
#       <th id="T_d599a_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_d599a_row2_col0" class="data row2 col0" >189815963.145000</td>
#       <td id="T_d599a_row2_col1" class="data row2 col1" >174387395.257397</td>
#       <td id="T_d599a_row2_col2" class="data row2 col2" >204226637.943981</td>
#       <td id="T_d599a_row2_col3" class="data row2 col3" >220698189.341096</td>
#     </tr>
#     <tr>
#       <th id="T_d599a_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_d599a_row3_col0" class="data row3 col0" >193555607.990000</td>
#       <td id="T_d599a_row3_col1" class="data row3 col1" >257431775.520000</td>
#       <td id="T_d599a_row3_col2" class="data row3 col2" >260380928.206829</td>
#       <td id="T_d599a_row3_col3" class="data row3 col3" >281743293.561500</td>
#     </tr>
#   </tbody>
# </table>

# %%
pivot.style.background_gradient(axis=None, cmap="RdYlGn")
# Out:
# <style type="text/css">
# #T_eb8c2_row0_col0 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_eb8c2_row0_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_eb8c2_row0_col2 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_eb8c2_row0_col3 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_eb8c2_row1_col0 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_eb8c2_row1_col1 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_eb8c2_row1_col2 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_eb8c2_row1_col3 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_eb8c2_row2_col0 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_eb8c2_row2_col1 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_eb8c2_row2_col2 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_eb8c2_row2_col3 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_eb8c2_row3_col0 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_eb8c2_row3_col1 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_eb8c2_row3_col2 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_eb8c2_row3_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_eb8c2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_eb8c2_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_eb8c2_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_eb8c2_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_eb8c2_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb8c2_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_eb8c2_row0_col0" class="data row0 col0" >79543730.870870</td>
#       <td id="T_eb8c2_row0_col1" class="data row0 col1" >75938908.509273</td>
#       <td id="T_eb8c2_row0_col2" class="data row0 col2" >106506262.001855</td>
#       <td id="T_eb8c2_row0_col3" class="data row0 col3" >131786300.675593</td>
#     </tr>
#     <tr>
#       <th id="T_eb8c2_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_eb8c2_row1_col0" class="data row1 col0" >121109886.855937</td>
#       <td id="T_eb8c2_row1_col1" class="data row1 col1" >113575111.328478</td>
#       <td id="T_eb8c2_row1_col2" class="data row1 col2" >140114760.005235</td>
#       <td id="T_eb8c2_row1_col3" class="data row1 col3" >160850043.261844</td>
#     </tr>
#     <tr>
#       <th id="T_eb8c2_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_eb8c2_row2_col0" class="data row2 col0" >189815963.145000</td>
#       <td id="T_eb8c2_row2_col1" class="data row2 col1" >174387395.257397</td>
#       <td id="T_eb8c2_row2_col2" class="data row2 col2" >204226637.943981</td>
#       <td id="T_eb8c2_row2_col3" class="data row2 col3" >220698189.341096</td>
#     </tr>
#     <tr>
#       <th id="T_eb8c2_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_eb8c2_row3_col0" class="data row3 col0" >193555607.990000</td>
#       <td id="T_eb8c2_row3_col1" class="data row3 col1" >257431775.520000</td>
#       <td id="T_eb8c2_row3_col2" class="data row3 col2" >260380928.206829</td>
#       <td id="T_eb8c2_row3_col3" class="data row3 col3" >281743293.561500</td>
#     </tr>
#   </tbody>
# </table>

# %%
pivot.style.background_gradient(subset=[2020, 2021], axis=None, cmap="RdYlGn")
# Out:
# <style type="text/css">
# #T_af3bb_row0_col0 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_af3bb_row0_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_af3bb_row1_col0 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_af3bb_row1_col1 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_af3bb_row2_col0 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_af3bb_row2_col1 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_af3bb_row3_col0 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_af3bb_row3_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_af3bb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_af3bb_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_af3bb_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_af3bb_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_af3bb_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af3bb_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_af3bb_row0_col0" class="data row0 col0" >79543730.870870</td>
#       <td id="T_af3bb_row0_col1" class="data row0 col1" >75938908.509273</td>
#       <td id="T_af3bb_row0_col2" class="data row0 col2" >106506262.001855</td>
#       <td id="T_af3bb_row0_col3" class="data row0 col3" >131786300.675593</td>
#     </tr>
#     <tr>
#       <th id="T_af3bb_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_af3bb_row1_col0" class="data row1 col0" >121109886.855937</td>
#       <td id="T_af3bb_row1_col1" class="data row1 col1" >113575111.328478</td>
#       <td id="T_af3bb_row1_col2" class="data row1 col2" >140114760.005235</td>
#       <td id="T_af3bb_row1_col3" class="data row1 col3" >160850043.261844</td>
#     </tr>
#     <tr>
#       <th id="T_af3bb_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_af3bb_row2_col0" class="data row2 col0" >189815963.145000</td>
#       <td id="T_af3bb_row2_col1" class="data row2 col1" >174387395.257397</td>
#       <td id="T_af3bb_row2_col2" class="data row2 col2" >204226637.943981</td>
#       <td id="T_af3bb_row2_col3" class="data row2 col3" >220698189.341096</td>
#     </tr>
#     <tr>
#       <th id="T_af3bb_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_af3bb_row3_col0" class="data row3 col0" >193555607.990000</td>
#       <td id="T_af3bb_row3_col1" class="data row3 col1" >257431775.520000</td>
#       <td id="T_af3bb_row3_col2" class="data row3 col2" >260380928.206829</td>
#       <td id="T_af3bb_row3_col3" class="data row3 col3" >281743293.561500</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 9.4. highlight_min / highlight_max

# %%
pivot.style.highlight_min()
# Out:
# <style type="text/css">
# #T_1bd0c_row0_col0, #T_1bd0c_row0_col1, #T_1bd0c_row0_col2, #T_1bd0c_row0_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_1bd0c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_1bd0c_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_1bd0c_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_1bd0c_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_1bd0c_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bd0c_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_1bd0c_row0_col0" class="data row0 col0" >79543730.870870</td>
#       <td id="T_1bd0c_row0_col1" class="data row0 col1" >75938908.509273</td>
#       <td id="T_1bd0c_row0_col2" class="data row0 col2" >106506262.001855</td>
#       <td id="T_1bd0c_row0_col3" class="data row0 col3" >131786300.675593</td>
#     </tr>
#     <tr>
#       <th id="T_1bd0c_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_1bd0c_row1_col0" class="data row1 col0" >121109886.855937</td>
#       <td id="T_1bd0c_row1_col1" class="data row1 col1" >113575111.328478</td>
#       <td id="T_1bd0c_row1_col2" class="data row1 col2" >140114760.005235</td>
#       <td id="T_1bd0c_row1_col3" class="data row1 col3" >160850043.261844</td>
#     </tr>
#     <tr>
#       <th id="T_1bd0c_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_1bd0c_row2_col0" class="data row2 col0" >189815963.145000</td>
#       <td id="T_1bd0c_row2_col1" class="data row2 col1" >174387395.257397</td>
#       <td id="T_1bd0c_row2_col2" class="data row2 col2" >204226637.943981</td>
#       <td id="T_1bd0c_row2_col3" class="data row2 col3" >220698189.341096</td>
#     </tr>
#     <tr>
#       <th id="T_1bd0c_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_1bd0c_row3_col0" class="data row3 col0" >193555607.990000</td>
#       <td id="T_1bd0c_row3_col1" class="data row3 col1" >257431775.520000</td>
#       <td id="T_1bd0c_row3_col2" class="data row3 col2" >260380928.206829</td>
#       <td id="T_1bd0c_row3_col3" class="data row3 col3" >281743293.561500</td>
#     </tr>
#   </tbody>
# </table>

# %%
pivot.style.highlight_min(axis=None)
# Out:
# <style type="text/css">
# #T_b5846_row0_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_b5846" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_b5846_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_b5846_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_b5846_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_b5846_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5846_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_b5846_row0_col0" class="data row0 col0" >79543730.870870</td>
#       <td id="T_b5846_row0_col1" class="data row0 col1" >75938908.509273</td>
#       <td id="T_b5846_row0_col2" class="data row0 col2" >106506262.001855</td>
#       <td id="T_b5846_row0_col3" class="data row0 col3" >131786300.675593</td>
#     </tr>
#     <tr>
#       <th id="T_b5846_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_b5846_row1_col0" class="data row1 col0" >121109886.855937</td>
#       <td id="T_b5846_row1_col1" class="data row1 col1" >113575111.328478</td>
#       <td id="T_b5846_row1_col2" class="data row1 col2" >140114760.005235</td>
#       <td id="T_b5846_row1_col3" class="data row1 col3" >160850043.261844</td>
#     </tr>
#     <tr>
#       <th id="T_b5846_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_b5846_row2_col0" class="data row2 col0" >189815963.145000</td>
#       <td id="T_b5846_row2_col1" class="data row2 col1" >174387395.257397</td>
#       <td id="T_b5846_row2_col2" class="data row2 col2" >204226637.943981</td>
#       <td id="T_b5846_row2_col3" class="data row2 col3" >220698189.341096</td>
#     </tr>
#     <tr>
#       <th id="T_b5846_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_b5846_row3_col0" class="data row3 col0" >193555607.990000</td>
#       <td id="T_b5846_row3_col1" class="data row3 col1" >257431775.520000</td>
#       <td id="T_b5846_row3_col2" class="data row3 col2" >260380928.206829</td>
#       <td id="T_b5846_row3_col3" class="data row3 col3" >281743293.561500</td>
#     </tr>
#   </tbody>
# </table>

# %%
pivot.style.highlight_min(axis=None, color="red")
# Out:
# <style type="text/css">
# #T_ccf91_row0_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_ccf91" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_ccf91_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_ccf91_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_ccf91_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_ccf91_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ccf91_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_ccf91_row0_col0" class="data row0 col0" >79543730.870870</td>
#       <td id="T_ccf91_row0_col1" class="data row0 col1" >75938908.509273</td>
#       <td id="T_ccf91_row0_col2" class="data row0 col2" >106506262.001855</td>
#       <td id="T_ccf91_row0_col3" class="data row0 col3" >131786300.675593</td>
#     </tr>
#     <tr>
#       <th id="T_ccf91_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_ccf91_row1_col0" class="data row1 col0" >121109886.855937</td>
#       <td id="T_ccf91_row1_col1" class="data row1 col1" >113575111.328478</td>
#       <td id="T_ccf91_row1_col2" class="data row1 col2" >140114760.005235</td>
#       <td id="T_ccf91_row1_col3" class="data row1 col3" >160850043.261844</td>
#     </tr>
#     <tr>
#       <th id="T_ccf91_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_ccf91_row2_col0" class="data row2 col0" >189815963.145000</td>
#       <td id="T_ccf91_row2_col1" class="data row2 col1" >174387395.257397</td>
#       <td id="T_ccf91_row2_col2" class="data row2 col2" >204226637.943981</td>
#       <td id="T_ccf91_row2_col3" class="data row2 col3" >220698189.341096</td>
#     </tr>
#     <tr>
#       <th id="T_ccf91_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_ccf91_row3_col0" class="data row3 col0" >193555607.990000</td>
#       <td id="T_ccf91_row3_col1" class="data row3 col1" >257431775.520000</td>
#       <td id="T_ccf91_row3_col2" class="data row3 col2" >260380928.206829</td>
#       <td id="T_ccf91_row3_col3" class="data row3 col3" >281743293.561500</td>
#     </tr>
#   </tbody>
# </table>

# %%
pivot.style.highlight_max(axis=None, color="green")
# Out:
# <style type="text/css">
# #T_fa8f0_row3_col3 {
#   background-color: green;
# }
# </style>
# <table id="T_fa8f0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_fa8f0_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_fa8f0_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_fa8f0_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_fa8f0_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa8f0_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_fa8f0_row0_col0" class="data row0 col0" >79543730.870870</td>
#       <td id="T_fa8f0_row0_col1" class="data row0 col1" >75938908.509273</td>
#       <td id="T_fa8f0_row0_col2" class="data row0 col2" >106506262.001855</td>
#       <td id="T_fa8f0_row0_col3" class="data row0 col3" >131786300.675593</td>
#     </tr>
#     <tr>
#       <th id="T_fa8f0_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_fa8f0_row1_col0" class="data row1 col0" >121109886.855937</td>
#       <td id="T_fa8f0_row1_col1" class="data row1 col1" >113575111.328478</td>
#       <td id="T_fa8f0_row1_col2" class="data row1 col2" >140114760.005235</td>
#       <td id="T_fa8f0_row1_col3" class="data row1 col3" >160850043.261844</td>
#     </tr>
#     <tr>
#       <th id="T_fa8f0_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_fa8f0_row2_col0" class="data row2 col0" >189815963.145000</td>
#       <td id="T_fa8f0_row2_col1" class="data row2 col1" >174387395.257397</td>
#       <td id="T_fa8f0_row2_col2" class="data row2 col2" >204226637.943981</td>
#       <td id="T_fa8f0_row2_col3" class="data row2 col3" >220698189.341096</td>
#     </tr>
#     <tr>
#       <th id="T_fa8f0_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_fa8f0_row3_col0" class="data row3 col0" >193555607.990000</td>
#       <td id="T_fa8f0_row3_col1" class="data row3 col1" >257431775.520000</td>
#       <td id="T_fa8f0_row3_col2" class="data row3 col2" >260380928.206829</td>
#       <td id="T_fa8f0_row3_col3" class="data row3 col3" >281743293.561500</td>
#     </tr>
#   </tbody>
# </table>

# %%
pivot.style.highlight_max(axis=None, color="green").highlight_min(axis=None, color="red")
# Out:
# <style type="text/css">
# #T_93a9e_row0_col1 {
#   background-color: red;
# }
# #T_93a9e_row3_col3 {
#   background-color: green;
# }
# </style>
# <table id="T_93a9e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_93a9e_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_93a9e_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_93a9e_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_93a9e_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93a9e_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_93a9e_row0_col0" class="data row0 col0" >79543730.870870</td>
#       <td id="T_93a9e_row0_col1" class="data row0 col1" >75938908.509273</td>
#       <td id="T_93a9e_row0_col2" class="data row0 col2" >106506262.001855</td>
#       <td id="T_93a9e_row0_col3" class="data row0 col3" >131786300.675593</td>
#     </tr>
#     <tr>
#       <th id="T_93a9e_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_93a9e_row1_col0" class="data row1 col0" >121109886.855937</td>
#       <td id="T_93a9e_row1_col1" class="data row1 col1" >113575111.328478</td>
#       <td id="T_93a9e_row1_col2" class="data row1 col2" >140114760.005235</td>
#       <td id="T_93a9e_row1_col3" class="data row1 col3" >160850043.261844</td>
#     </tr>
#     <tr>
#       <th id="T_93a9e_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_93a9e_row2_col0" class="data row2 col0" >189815963.145000</td>
#       <td id="T_93a9e_row2_col1" class="data row2 col1" >174387395.257397</td>
#       <td id="T_93a9e_row2_col2" class="data row2 col2" >204226637.943981</td>
#       <td id="T_93a9e_row2_col3" class="data row2 col3" >220698189.341096</td>
#     </tr>
#     <tr>
#       <th id="T_93a9e_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_93a9e_row3_col0" class="data row3 col0" >193555607.990000</td>
#       <td id="T_93a9e_row3_col1" class="data row3 col1" >257431775.520000</td>
#       <td id="T_93a9e_row3_col2" class="data row3 col2" >260380928.206829</td>
#       <td id="T_93a9e_row3_col3" class="data row3 col3" >281743293.561500</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 9.4. 한번에 적용하기

# %%
s= pivot.style
s = s.background_gradient(subset=[2020, 2021], axis=None, cmap="RdYlGn")
s = s.bar(subset=[2022, 2023], cmap="Blues", props="width: 300px;", vmin=0, vmax=500000000)
s = s.format(subset=[2020])
s = s.format(subset=[2021], formatter="{:.0f}")
s = s.format(subset=[2022], formatter="{:.3f}")
s = s.format(subset=[2023], formatter="{:,.0f}")
s = s.highlight_max(axis=None, color="green")
s
# Out:
# <style type="text/css">
# #T_4ce10_row0_col0 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_4ce10_row0_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_4ce10_row0_col2 {
#   width: 300px;
#   background: linear-gradient(90deg, #cde0f1 21.3%, transparent 21.3%);
# }
# #T_4ce10_row0_col3 {
#   width: 300px;
#   background: linear-gradient(90deg, #c2d9ee 26.4%, transparent 26.4%);
# }
# #T_4ce10_row1_col0 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_4ce10_row1_col1 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_4ce10_row1_col2 {
#   width: 300px;
#   background: linear-gradient(90deg, #bdd7ec 28.0%, transparent 28.0%);
# }
# #T_4ce10_row1_col3 {
#   width: 300px;
#   background: linear-gradient(90deg, #afd1e7 32.2%, transparent 32.2%);
# }
# #T_4ce10_row2_col0 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_4ce10_row2_col1 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_4ce10_row2_col2 {
#   width: 300px;
#   background: linear-gradient(90deg, #91c3de 40.8%, transparent 40.8%);
# }
# #T_4ce10_row2_col3 {
#   width: 300px;
#   background: linear-gradient(90deg, #84bcdb 44.1%, transparent 44.1%);
# }
# #T_4ce10_row3_col0 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_4ce10_row3_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_4ce10_row3_col2 {
#   width: 300px;
#   background: linear-gradient(90deg, #64a9d3 52.1%, transparent 52.1%);
# }
# #T_4ce10_row3_col3 {
#   width: 300px;
#   background: linear-gradient(90deg, #56a0ce 56.3%, transparent 56.3%);
#   background-color: green;
# }
# </style>
# <table id="T_4ce10" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >근무연도</th>
#       <th id="T_4ce10_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_4ce10_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_4ce10_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_4ce10_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >경험수준_한글</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ce10_level0_row0" class="row_heading level0 row0" >신입</th>
#       <td id="T_4ce10_row0_col0" class="data row0 col0" >79543730.870870</td>
#       <td id="T_4ce10_row0_col1" class="data row0 col1" >75938909</td>
#       <td id="T_4ce10_row0_col2" class="data row0 col2" >106506262.002</td>
#       <td id="T_4ce10_row0_col3" class="data row0 col3" >131,786,301</td>
#     </tr>
#     <tr>
#       <th id="T_4ce10_level0_row1" class="row_heading level0 row1" >중간</th>
#       <td id="T_4ce10_row1_col0" class="data row1 col0" >121109886.855937</td>
#       <td id="T_4ce10_row1_col1" class="data row1 col1" >113575111</td>
#       <td id="T_4ce10_row1_col2" class="data row1 col2" >140114760.005</td>
#       <td id="T_4ce10_row1_col3" class="data row1 col3" >160,850,043</td>
#     </tr>
#     <tr>
#       <th id="T_4ce10_level0_row2" class="row_heading level0 row2" >고위</th>
#       <td id="T_4ce10_row2_col0" class="data row2 col0" >189815963.145000</td>
#       <td id="T_4ce10_row2_col1" class="data row2 col1" >174387395</td>
#       <td id="T_4ce10_row2_col2" class="data row2 col2" >204226637.944</td>
#       <td id="T_4ce10_row2_col3" class="data row2 col3" >220,698,189</td>
#     </tr>
#     <tr>
#       <th id="T_4ce10_level0_row3" class="row_heading level0 row3" >임원</th>
#       <td id="T_4ce10_row3_col0" class="data row3 col0" >193555607.990000</td>
#       <td id="T_4ce10_row3_col1" class="data row3 col1" >257431776</td>
#       <td id="T_4ce10_row3_col2" class="data row3 col2" >260380928.207</td>
#       <td id="T_4ce10_row3_col3" class="data row3 col3" >281,743,294</td>
#     </tr>
#   </tbody>
# </table>

# %%
s.to_excel("pivot.xlsx")

# %% [markdown]
# ---
